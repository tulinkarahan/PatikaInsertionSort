# %% [markdown]
# <a href="https://colab.research.google.com/github/tulinkarahan/PatikaInsertionSort/blob/main/Start_here.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <table width="100%">
#     <tr style="">
#         <th style="text-align:left; padding:0px" width="5%">
#             <a href="https://www.marmara.edu.tr" target="_blank">
#                 <img src="https://raw.githubusercontent.com/MU-Physics-Department/logos/master/mu_logo.png">
#             </a>
#         </th>
#         <th style="padding:0px;" width="35%">
#             <img align="right" src="https://raw.githubusercontent.com/MU-Physics-Department/logos/master/name.png">
#         </th>
#         <th  width="20%">
#             &nbsp;
#         </th>
#         <th style="padding:0px" width="5%">
#             <a href="https://www.sababozpolat.com" target="_blank" padding="0px">
#                 <img align="center" src="https://raw.githubusercontent.com/MU-Physics-Department/logos/master/hp.png">
#             </a>
#         </th>
#         <th style="padding:0px" width="5%">
#             <a href="mailto:saba.bozpolat@gmail.com" target="_blank">
#                 <img align="center" src="https://raw.githubusercontent.com/MU-Physics-Department/logos/master/email.png">
#             </a>
#         </th>
#         <th style="padding:0px;" width="5%">
#             <a href="https://www.linkedin.com/in/saba-bozpolat-644856152/" target="_blank">
#                 <img align="right" src="https://raw.githubusercontent.com/MU-Physics-Department/logos/master/in.png">
#             </a>
#         </th>
#         <th style="padding:0px;" width="5%">
#             <a href="https://scholar.google.com.tr/citations?user=nSiJoMYAAAAJ&hl=en" target="_blank">
#                 <img align="right" src="https://raw.githubusercontent.com/MU-Physics-Department/logos/master/GS.png">
#             </a>
#         </th>
#         <th style="padding:0px;" width="5%">
#             <a href="https://www.researchgate.net/profile/Saba-Bozpolat" target="_blank">
#                 <img align="right" src="https://raw.githubusercontent.com/MU-Physics-Department/logos/master/RG.png">
#             </a>
#         </th>
#         <th style="padding:0px" width="5%">
#             <a href="https://www.youtube.com/channel/UC8-uOZud6UL7oCOE2UUBunA" target="_blank">
#                 <img align="right" src="https://raw.githubusercontent.com/MU-Physics-Department/logos/master/YT.png">
#             </a>
#         </th>
#         <th style="padding:0px;" width="5%">
#             <a href="https://github.com/sbbzplt" target="_blank">
#                 <img align="right" src="https://raw.githubusercontent.com/MU-Physics-Department/logos/master/GH.png">
#             </a>
#         </th>
#         <th style="padding:0px;" width="5%">
#             <a href="https://join.slack.com/t/mu-fzk/shared_invite/zt-13jtd6dtd-g9zD5P4Zu0m5P0Gt2PNReQ"
#                target="_blank">
#                 <img align="right" src="https://raw.githubusercontent.com/MU-Physics-Department/logos/master/slack.png">
#             </a>
#         </th>
#     </tr>
# </table>
# <table width="100%">
#     <tr style="background-color:white;">
#         <td style="padding:0px" width="25%">
#             <a href="http://fzk.fen.marmara.edu.tr"
#                target="_blank">
#                 <img align="right" src="https://raw.githubusercontent.com/MU-Physics-Department/logos/master/fzk.png">
#             </a>
#         </td>
#         <td width="10%">
#             &nbsp;
#         </td>
#         <td style="padding:0px;" width="65%">
#             <a href="https://www.sababozpolat.com/lectures/spring-semester/scientific-programming"
#                target="_blank">
#                 <img align="right" src="https://raw.githubusercontent.com/MU-Physics-Department/logos/master/comp2083.png">
#             </a>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # **TABLE OF CONTENTS**

# %% [markdown]
# ### **Supporting Documents**
#
# [Colab](content/intro/II_02_colab.ipynb)
# &nbsp;|&nbsp;
# [Github](content/intro/II_03_github.ipynb)
# &nbsp;|&nbsp;
# [Canvas](content/intro/II_04_canvas.ipynb)
# &nbsp;|&nbsp;
# [Slack](content/intro/II_05_slack.ipynb)

# %% [markdown]
# ## **Volume 1 - Fundamentals of Programming**

# %% [markdown]
# ## Basics of Computational Technologies
#
# [What is a computer?](content/basics/BB_04_what_is_a_computer.ipynb)
# &nbsp;|&nbsp;
# [Inside a computer](content/basics/BB_08_inside_a_computer.ipynb)
# &nbsp;|&nbsp;
# [Hardware](content/basics/BB_12_hardware.ipynb)
# &nbsp;|&nbsp;
# [Software](content/basics/BB_16_software.ipynb)
# &nbsp;|&nbsp;
# [Programming Languages](content/basics/BB_20_programming_language.ipynb)
# <!-- &nbsp;|&nbsp; -->

# %% [markdown]
# ## Fundamentals of Algorithm
#
# [What is an algorithm?](content/algorithm/Algo04_what_is_an_algorithm.ipynb)
# &nbsp;|&nbsp;
# [Computer algorithms](content/algorithm/Algo08_computer_algorithms.ipynb)
# <!-- &nbsp;|&nbsp; -->

# %% [markdown]
# ## Primitive Types and Data Storage
#
# [Integer](content/python/Data04_integer.ipynb)
# &nbsp;|&nbsp;
# [Float](content/python/Data08_float.ipynb)
# &nbsp;|&nbsp;
# [Variable](content/python/Data12_variable.ipynb)
# &nbsp;|&nbsp;
# [Assignment Operator](content/python/Operator04_assignment_operator.ipynb)
# &nbsp;|&nbsp;
# [String](content/python/Data16_string.ipynb)
# &nbsp;|&nbsp;
# [Boolean](content/python/Data20_boolean.ipynb)
# &nbsp;|&nbsp;
# [Type Casting](content/python/Data24_type_casting.ipynb)
# <!-- &nbsp;|&nbsp; -->

# %% [markdown]
# ## Broad Exercises \#1
#
# [Exercise Set 1](content/python/Ex04_set1.ipynb)
# &nbsp;|&nbsp;
# [Exercise Set 2](content/python/Ex08_set2.ipynb)
# <!-- &nbsp;|&nbsp; -->

# %% [markdown]
# ## Data Containers
# [List](content/python/Container04_list.ipynb)
# &nbsp;|&nbsp;
# [Set](content/python/Container08_set.ipynb)
# &nbsp;|&nbsp;
# [Tuple](content/python/Container12_tuple.ipynb)
# &nbsp;|&nbsp;
# [Dictionary](content/python/Container16_dictionary.ipynb)
# &nbsp;|&nbsp;
# [Type Casting for Data Containers](content/python/Container20_type_casting.ipynb)
# <!-- &nbsp;|&nbsp; -->

# %% [markdown]
# ## Fundamental Operators
#
# [Arithmetic Operators](content/python/Operator08_arithmetic_operators.ipynb)
# &nbsp;|&nbsp;
# [In-Place Assignment Operators](content/python/Operator12_assignment_operators.ipynb)
# &nbsp;|&nbsp;
# [Comparison Operators](content/python/Operator16_comparison_operators.ipynb)
# &nbsp;|&nbsp;
# [Bitwise Operators](content/python/Operator20_bitwise_operators.ipynb)
# <!-- &nbsp;|&nbsp; -->
# [Logical Operators](content/python/Operator24_logical_operators.ipynb)
# &nbsp;|&nbsp;
# [Membership and Identity Operators](content/python/Operator28_membership_and_identity_operators.ipynb)
# &nbsp;|&nbsp;
# [Operators Precedence](content/python/Operator32_operators_precedence.ipynb)
# <!-- &nbsp;|&nbsp; -->

# %% [markdown]
# ## Broad Exercises \#2
#
# [Exercise Set 3](content/python/Ex12_set3.ipynb)
# &nbsp;|&nbsp;
# [Exercise Set 4](content/python/Ex16_set4.ipynb)
# <!-- &nbsp;|&nbsp; -->

# %% [markdown]
# ## Python Modules
#
# [Built-in Modules](content/python/Python04_builtins.ipynb)
# &nbsp;|&nbsp;
# [Python Package Index (PyPI)](content/python/Python08_pypi.ipynb)
# <!-- &nbsp;|&nbsp; -->

# %% [markdown]
# ## Loops
#
# [General Structure of Loops](content/python/Loop04_general_structure.ipynb)
# &nbsp;|&nbsp;
# [While Loops](content/python/Loop08_while.ipynb)
# &nbsp;|&nbsp;
# [For Loops](content/python/Loop12_for.ipynb)
# <!-- &nbsp;|&nbsp; -->

# %% [markdown]
# ## Decision Making
#
# [Boolean - Extended](content/python/Data28_boolean_extended.ipynb)
# &nbsp;|&nbsp;
# [Conditions and Branching](content/python/Decision04_conditions_and_brancing.ipynb)
# &nbsp;|&nbsp;
# [If Blocks](content/python/Decision08_if.ipynb)
# &nbsp;|&nbsp;
# [Single Variables as Logical Propositions](content/python/Decision12_single_vars_as_logical_prop.ipynb)
# <!-- &nbsp;|&nbsp; -->
# [Nested If Blocks](content/python/Decision16_nested_if.ipynb)
# &nbsp;|&nbsp;
# [Loop Control Statements](content/python/Loop16_control_statements.ipynb)
# <!-- &nbsp;|&nbsp; -->

# %% [markdown]
# ## Broad Exercises \#3
# [Exercise Set 5](content/python/Ex20_set5.ipynb)
# &nbsp;|&nbsp;
# [Exercise Set 6](content/python/Ex24_set6.ipynb)
# <!-- &nbsp;|&nbsp; -->

# %% [markdown]
# ## Functions
#
# [What is a function?](content/python/Func04_function.ipynb)
# &nbsp;|&nbsp;
# [Recursive functions](content/python/Func08_recursive_function.ipynb)
# &nbsp;|&nbsp;
# [Global & Local Scopes](content/python/Func12_scopes.ipynb)
# &nbsp;|&nbsp;
# [Argument Types](content/python/Func16_different_inputs.ipynb)
# <!-- &nbsp;|&nbsp; -->

# %% [markdown]
# ## Python One-Liners
# [Comprehensive Loops](content/python/Python12_comprehensive_loops.ipynb)
# &nbsp;|&nbsp;
# [Comprehensive If Blocks](content/python/Python16_comprehensive_ifs.ipynb)
# &nbsp;|&nbsp;
# [Lambda Functions](content/python/Python20_lambda_functions.ipynb)
# <!-- &nbsp;|&nbsp; -->

# %% [markdown]
# ## Broad Exercises \#4
# [Exercise Set 7](content/python/Ex28_set7.ipynb)
# &nbsp;|&nbsp;
# [Exercise Set 8](content/python/Ex32_set8.ipynb)
# <!-- &nbsp;|&nbsp; -->

# %% [markdown]
# ## Code Testing in Python
# [Testing Fundamentals](content/python/Test04_fundamentals.ipynb)
# &nbsp;|&nbsp;
# [Manual Testing](content/python/Test08_manual_testing.ipynb)
# <!-- &nbsp;|&nbsp; -->

# %% [markdown]
# ----------------------------
# ----------------------------
# ----------------------------
# ## **Volume 2 - Fundamentals of Data Analysis**

# %% [markdown]
# ## Data Visualization
# [Matplotlib Module](content/data_visualization/Visual04_Matplotlib.ipynb)

# %% [markdown]
# ## Introduction to Machine Learning
# [Basics of Machine Learning](content/machine_learning/ML04_basics_of_ml.ipynb)
# &nbsp;|&nbsp;
# [Basics of Deep Learning](content/machine_learning/ML08_basics_of_dl.ipynb)
# <!-- &nbsp;|&nbsp; -->

# %% [markdown]
# ## Regression
# [Fit & Regression](content/regression/RG04_fit_and_regression.ipynb)
# &nbsp;|&nbsp;
# [Linear Fit Applications](content/regression/RG08_linear_fit_apps.ipynb)
# &nbsp;|&nbsp;
# [Exponential Fit](content/DE_29_Numerical_Derivation.ipynb)
# &nbsp;|&nbsp;
# [Exponential Fit Applications](content/DE_29_Numerical_Derivation.ipynb)
# <!-- &nbsp;|&nbsp; -->

# %% [markdown]
# ----------------------------
# ----------------------------
# ----------------------------
# ## **Volume 3 - Fundamentals of Scientific Programming**

# %% [markdown]
# ## From Continuum to Grid
#
# <!-- [Symbolic Calculation](content/grid/GR04_symbolic.ipynb) -->
# <!-- &nbsp;|&nbsp; -->
# [Grid](content/grid/GR08_grid.ipynb)
# &nbsp;|&nbsp;
# [Grid - Applications](content/grid/GR12_grid_apps.ipynb)
# <!-- &nbsp;|&nbsp; -->

# %% [markdown]
# ## First Order Numerical Derivation
#
# [Numerical Derivation](content/scientifics/Drv04_derivation.ipynb)
# &nbsp;|&nbsp;
# [Derivation Applications](content/scientifics/Drv08_derivation_applications.ipynb)
# <!-- &nbsp;|&nbsp; -->

# %% [markdown]
# ## Higher Order Numerical Derivation
#
# [Higher Order Derivation](content/scientifics/Drv12_higher_order_derivation.ipynb)
# &nbsp;|&nbsp;
# [Higher Order Derivation - Applications](content/scientifics/Drv16_higher_order_derivation_applications.ipynb)
# <!-- &nbsp;|&nbsp; -->

# %% [markdown]
# ## Numerical Integration
#
# [Trapezoidal Method](content/scientifics/Integal04_trapezoidal.ipynb)
# &nbsp;|&nbsp;
# [Trapezoidal Method - Applications](content/scientifics/Integal08_trapezoidal_applications.ipynb)
# <!-- &nbsp;|&nbsp; -->
# <!-- [Secant Method](content/scientifics/Integal12_secant.ipynb) -->
# <!-- &nbsp;|&nbsp; -->
# <!-- [Secant Method - Applications](content/scientifics/Integal16_secant_applications.ipynb) -->
# <!-- &nbsp;|&nbsp; -->

# %% [markdown]
# ## Numerical Solutions for Differential Equations
#
# [Euler's Method](content/scientifics/DiffEq04_euler.ipynb)
# &nbsp;|&nbsp;
# [Electricity and Magnetism Applications](content/physics%20applications/Phys04_elec_and_mag.ipynb)
# &nbsp;|&nbsp;
# [Modern Physics Applications](content/physics%20applications/Phys08_modern_phys.ipynb)
# <!-- &nbsp;|&nbsp; -->
# [Order Reduction of Differential Equations](content/scientifics/DiffEq08_order_reduction.ipynb)
# &nbsp;|&nbsp;
# [Mechanics Applications](content/physics%20applications/Phys12_mechanics.ipynb)
# &nbsp;|&nbsp;
# [Euler-Cromer Method](content/scientifics/DiffEq12_euler_cromer.ipynb)

# %% [markdown]
# ## Numerical Solutions to Eigenvalue Problem
#
# [Power Iteration Method](content/scientifics/EigenEq04_power_iter.ipynb)
# &nbsp;|&nbsp;
# [Quantum Mechanics Applications (Ground State)](content/physics%20applications/Phys16_quantum_mech.ipynb)
# <!-- &nbsp;|&nbsp; -->
# [QR Iteration Method](content/scientifics/DiffEem_applications.ipynb)
# &nbsp;|&nbsp;
# [Shooting Method](content/scientifics/DiffEem_applications.ipynb)
# &nbsp;|&nbsp;
# [Numerov Method](content/scientifics/DiffEem_applications.ipynb)
# <!-- &nbsp;|&nbsp; -->
# [Quantum Mechanics Applications (Excited States)](content/physics%20applications/Phys20_quantum_mech.ipynb)
# <!-- &nbsp;|&nbsp; -->
# <!-- [Quantum Mechanics Applications (Excited States)](content/physics%20applications/Phys20_quantum_mech.ipynb) -->
# <!-- &nbsp;|&nbsp; -->

# %% [markdown]
# ## Linear Equation Systems
# [Linear Algebraic Equations](content/scientifics/LinAlg04_definition.ipynb)
# &nbsp;|&nbsp;
# [Cromer's Rule](content/scientifics/LinAlg08_cromers_rule.ipynb)
# &nbsp;|&nbsp;
# [Electronics Applications](content/physics%20applications/Phys24_electronics.ipynb)
# <!-- &nbsp;|&nbsp; -->

# %% [markdown]
# ----------------------------
# ----------------------------
# ----------------------------
# ## **Volume 4 - Advanced Scientific Programming**

# %% [markdown]
# ## Randomized Algorithms
# [Sampling and Randomized Sampling](content/sampling/RA04_sampling.ipynb)
# &nbsp;|&nbsp;
# [Gaussian Distribution and Random Walk](content/sampling/RA08_random_walk.ipynb)
# <!-- &nbsp;|&nbsp; -->
# [Monte Carlo Method and Algorithm](content/sampling/RA12_monte_carlo.ipynb)
# &nbsp;|&nbsp;
# [Monte Carlo Applications](content/sampling/RA16_monte_carlo_apps.ipynb)
# &nbsp;|&nbsp;
# [Ising Model with Monte Carlo](content/sampling/RA20_ising_model.ipynb)
# <!-- &nbsp;|&nbsp; -->

# %% [markdown]
# # **Projects**
#
# &#9734;&#9734;&#9734;&nbsp;|&nbsp;[Perfect Numbers](content/projects/Prj04_perfect_numbers.ipynb)<br>
# &#9734;&#9734;&#9734;&nbsp;|&nbsp;[Another Formula for Factorial](content/projects/Prj12_another_formula_for_factorial.ipynb)<br>
# &#9734;&#9734;&#9733;&nbsp;|&nbsp;[Drunkard's Walk](content/projects/Prj20_drunkards_walk.ipynb)<br>
# &#9734;&#9734;&#9733;&nbsp;|&nbsp;[Escape The Dragon Cave](content/projects/Prj16_escape_the_dragon_cave.ipynb)<br>
# &#9734;&#9733;&#9733;&nbsp;|&nbsp;[Kaprekar's Constant](content/projects/Prj32_kaprekars_contant.ipynb)

# %% [markdown]
# # Intended Calendar

# %% [markdown]
# ![image.png](data:image/png;base64,...)
